# %%
import logging

# %%
logging.basicConfig(
    filename = "first.log",
    encoding = "utf-8",
    filemode = "a",
    format = "{asctime} - {levelname} - {message}",
    style = "{",
    datefmt = "%d-%m-%Y : %H:%M",
    level = "DEBUG"
)

# %%
logging.warning("This is debug mode!")

# %%
import logging

# %%
logging.basicConfig(
    filename="app.log",
    encoding="utf-8",
    filemode="a",
    format="{asctime} - {levelname} - {message}",
    style="{",
    datefmt="%Y-%m-%d %H:%M",
)

# %%
logging.warning("Save me!")

# %%
import logging
logger = logging.getLogger(__name__)
print(logger.name)
logger.warning("Look at my logger!")
# Out:
# Look at my logger!
# __main__

# %%
print(__name__)
# Out:
# __main__

# %%
# a.py
print(__name__)
# Out:
# __main__

# %%
console_handler = logging.StreamHandler()
file_handler = logging.FileHandler("demo.log",mode="a",encoding="utf-8")

# %%
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# %%
logger.handlers
# Out:
# [<StreamHandler stderr (NOTSET)>,
#  <FileHandler D:\Learning\Reversebits\Python\reverseBits\demo.log (NOTSET)>]
